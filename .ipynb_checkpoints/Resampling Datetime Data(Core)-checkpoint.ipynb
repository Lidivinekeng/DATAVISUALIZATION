# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

url ="https://docs.google.com/spreadsheets/d/e/2PACX-1vT_jChgNsQbHbg4TGepzIqk8XC9DTIKmyyxb1upo5cfZCgbfIUQc2ZC0YMzuU5uApP140Ob49KBjdqh/pub?gid=1198589591&single=true&output=csv"
df = pd.read_csv(url)
df
# Out:
#            date  cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# 0      19790101          2.0       7.0              52.0       2.3       -4.1
# 1      19790102          6.0       1.7              27.0       1.6       -2.6
# 2      19790103          5.0       0.0              13.0       1.3       -2.8
# 3      19790104          8.0       0.0              13.0      -0.3       -2.6
# 4      19790105          6.0       2.0              29.0       5.6       -0.8
# ...         ...          ...       ...               ...       ...        ...
# 15336  20201227          1.0       0.9              32.0       7.5        7.5
# 15337  20201228          7.0       3.7              38.0       3.6        1.1
# 15338  20201229          7.0       0.0              21.0       4.1        2.6
# 15339  20201230          6.0       0.4              22.0       5.6        2.7
# 15340  20201231          7.0       1.3              34.0       1.5       -0.8
#
# ...

# %% [markdown]
# ## Convert the date column to datetime dtype.

# %%
pd.to_datetime(df['date'])
# Out:
# 0       1970-01-01 00:00:00.019790101
# 1       1970-01-01 00:00:00.019790102
# 2       1970-01-01 00:00:00.019790103
# 3       1970-01-01 00:00:00.019790104
# 4       1970-01-01 00:00:00.019790105
#                      ...
# 15336   1970-01-01 00:00:00.020201227
# 15337   1970-01-01 00:00:00.020201228
# 15338   1970-01-01 00:00:00.020201229
# 15339   1970-01-01 00:00:00.020201230
# 15340   1970-01-01 00:00:00.020201231
# Name: date, Length: 15341, dtype: datetime64[ns]

# %%
#conversion 
df['date'] = pd.to_datetime(df['date'], format='%Y%m%d')
df['date']
# Out:
# 0       1979-01-01
# 1       1979-01-02
# 2       1979-01-03
# 3       1979-01-04
# 4       1979-01-05
#            ...
# 15336   2020-12-27
# 15337   2020-12-28
# 15338   2020-12-29
# 15339   2020-12-30
# 15340   2020-12-31
# Name: date, Length: 15341, dtype: datetime64[ns]

# %% [markdown]
# ## Set the date column as the index.

# %%
df = df.set_index('date')
df
# Out:
#             cloud_cover  sunshine  global_radiation  max_temp  mean_temp  \
# date
# 1979-01-01          2.0       7.0              52.0       2.3       -4.1
# 1979-01-02          6.0       1.7              27.0       1.6       -2.6
# 1979-01-03          5.0       0.0              13.0       1.3       -2.8
# 1979-01-04          8.0       0.0              13.0      -0.3       -2.6
# 1979-01-05          6.0       2.0              29.0       5.6       -0.8
# ...                 ...       ...               ...       ...        ...
# 2020-12-27          1.0       0.9              32.0       7.5        7.5
# 2020-12-28          7.0       3.7              38.0       3.6        1.1
# 2020-12-29          7.0       0.0              21.0       4.1        2.6
# 2020-12-30          6.0       0.4              22.0       5.6        2.7
# 2020-12-31          7.0       1.3              34.0       1.5       -0.8
#
#             min_temp  precipitation  pressure  snow_depth
# date
# ...

# %% [markdown]
# ## Filter out only the required data:

# %% [markdown]
# ### Keep only data from the year 2000 or later and Keep only the following features

# %%
df_filtered = df.loc['2000':, ['precipitation', 'mean_temp', 'min_temp', 
                      'max_temp', 'snow_depth']]

df_filtered
# Out:
#             precipitation  mean_temp  min_temp  max_temp  snow_depth
# date
# 2000-01-01            0.0        7.0       4.9      10.8         0.0
# 2000-01-02            0.2        7.9       5.0      11.5         0.0
# 2000-01-03            6.0        9.4       7.2       9.5         0.0
# 2000-01-04            0.2        7.0       4.4      11.0         0.0
# 2000-01-05            0.8        6.4       1.9      10.8         0.0
# ...                   ...        ...       ...       ...         ...
# 2020-12-27            2.0        7.5       7.6       7.5         NaN
# 2020-12-28            0.2        1.1      -1.3       3.6         NaN
# 2020-12-29            0.0        2.6       1.1       4.1         NaN
# 2020-12-30            0.0        2.7      -0.1       5.6         NaN
# 2020-12-31            0.0       -0.8      -3.1       1.5         NaN
#
# [7671 rows x 5 columns]

# %% [markdown]
# ## What month had the most precipitation between 2000 through 2010?

# %%
df_filtered.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_q1 = df_filtered['precipitation'].resample('M').sum()

df_q1
# Out:
# date
# 2000-01-31     14.3
# 2000-02-29     62.2
# 2000-03-31     13.4
# 2000-04-30     71.8
# 2000-05-31     68.4
#               ...
# 2020-08-31     45.2
# 2020-09-30     19.2
# 2020-10-31    143.4
# 2020-11-30     47.8
# 2020-12-31     56.4
# Freq: M, Name: precipitation, Length: 252, dtype: float64

# %%
# Find the date and corresponding value for the max precipitation
max_precipitation_date = df_q1.idxmax()

max_precipitation_date
# Out:
# Timestamp('2014-01-31 00:00:00', freq='M')

# %%
max_precipitation_value = df_q1.max()

max_precipitation_value
# Out:
# 148.6

# %%
# Plotting Q1
fig, ax = plt.subplots(figsize=(12, 3))
df_q1.plot(ax=ax)
ax.axvline(max_precipitation_date, color='r', linestyle='--', label=f'Max Precipitation\n{max_precipitation_date.strftime("%B %Y")}: {max_precipitation_value} inches')
ax.set_title('Precipitation for 2000-2010')
ax.set_ylabel('Inches')
ax.legend()
ax.xaxis.set_major_locator(plt.MaxNLocator(6))
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: pd.to_datetime(x).strftime('%Y')))
ax.xaxis.set_minor_locator(plt.MultipleLocator(3))
ax.xaxis.set_minor_formatter(plt.NullFormatter())
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Which year between 2000-2020 had the coolest average temperature?

# %%
#Resample the  mean_temp data to a Yearly frequency using .mean() as the aggregation method.
df_q2 = df_filtered['mean_temp'].resample('Y').mean()

df_q2
# Out:
# date
# 2000-12-31    11.532070
# 2001-12-31    11.313006
# 2002-12-31    12.006286
# 2003-12-31    12.232764
# 2004-12-31    11.872046
# 2005-12-31    11.879883
# 2006-12-31    12.387941
# 2007-12-31    12.063717
# 2008-12-31    11.174855
# 2009-12-31    11.722254
# 2010-12-31    10.645773
# 2011-12-31    12.474566
# 2012-12-31    11.323907
# 2013-12-31    11.202017
# 2014-12-31    12.613881
# 2015-12-31    12.091884
# 2016-12-31    11.894602
# 2017-12-31    12.238506
# 2018-12-31    12.440922
# 2019-12-31    12.229070
# 2020-12-31    12.717117
# Freq: A-DEC, Name: mean_temp, dtype: float64

# %%
 #Find the date and value for the lowest mean temp
lowest_mean_temp_date = df_q2.idxmin()

lowest_mean_temp_date
# Out:
# Timestamp('2010-12-31 00:00:00', freq='A-DEC')

# %%
lowest_mean_temp_value = df_q2.min()

lowest_mean_temp_value
# Out:
# 10.645772594752186

# %%
# Plotting Q2
fig, ax = plt.subplots(figsize=(12, 3))
df_q2.plot(ax=ax)
ax.axvline(lowest_mean_temp_date, color='r', linestyle='--', label=f'Lowest Mean Temp\n{lowest_mean_temp_date.year}: {lowest_mean_temp_value} degrees')
ax.set_title('Average Temperature')
ax.set_ylabel('Degrees')
ax.legend()
ax.xaxis.set_major_locator(plt.MaxNLocator(5))
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: pd.to_datetime(x).strftime('%Y')))
ax.xaxis.set_minor_locator(plt.MultipleLocator(1))
ax.xaxis.set_minor_formatter(plt.NullFormatter())
plt.xticks(rotation=90)
plt.show()
